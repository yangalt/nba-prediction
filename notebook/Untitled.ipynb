# %%
pip install nba_api
# Out:
# ...
#   Created wheel for nba-api: filename=nba_api-1.1.11-py3-none-any.whl size=251504 sha256=6d2f78b0408d1125cb35ef80d184ff19c5cc416835daa3884da8555573638b1b
#   Stored in directory: c:\users\jack\appdata\local\pip\cache\wheels\66\c2\3b\c87a243f9e5d2449e7f2c7bd65de4a6b5ce9a24b33978398a7
# Successfully built nba-api
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request, urllib.parse, urllib.error
import re
import pandas as pd
import requests as rq
from bs4 import BeautifulSoup
import json
from ipywidgets import interact

# %%
from nba_api.stats.endpoints import playercareerstats
from nba_api.stats.static import players
from nba_api.stats.static import teams
from nba_api.stats.endpoints import commonteamroster
from nba_api.stats.endpoints import playergamelog
from nba_api.stats.endpoints import teamgamelog
from nba_api.stats.endpoints import leaguestandings

# %%
from nba_api.stats.endpoints import leaguegamelog
leaguegame=leaguegamelog.LeagueGameLog(0,season=2021).get_data_frames()[0]
leaguegame
# Out:
#      SEASON_ID     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        22021  1610612747               LAL      Los Angeles Lakers
# 1        22021  1610612744               GSW   Golden State Warriors
# 2        22021  1610612751               BKN           Brooklyn Nets
# 3        22021  1610612749               MIL         Milwaukee Bucks
# 4        22021  1610612754               IND          Indiana Pacers
# 5        22021  1610612766               CHA       Charlotte Hornets
# 6        22021  1610612765               DET         Detroit Pistons
# 7        22021  1610612741               CHI           Chicago Bulls
# 8        22021  1610612761               TOR         Toronto Raptors
# 9        22021  1610612764               WAS      Washington Wizards
# 10       22021  1610612740               NOP    New Orleans Pelicans
# 11       22021  1610612755               PHI      Philadelphia 76ers
# 12       22021  1610612739               CLE     Cleveland Cavaliers
# ...

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2
game_id='0022100001'
leaguegame=boxscoreadvancedv2.BoxScoreAdvancedV2(game_id).get_data_frames()[1]
leaguegame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   GAME_ID            2 non-null      object
#  1   TEAM_ID            2 non-null      int64
#  2   TEAM_NAME          2 non-null      object
#  3   TEAM_ABBREVIATION  2 non-null      object
#  4   TEAM_CITY          2 non-null      object
#  5   MIN                2 non-null      object
#  6   E_OFF_RATING       2 non-null      float64
#  7   OFF_RATING         2 non-null      float64
#  8   E_DEF_RATING       2 non-null      float64
#  9   DEF_RATING         2 non-null      float64
#  10  E_NET_RATING       2 non-null      float64
#  11  NET_RATING         2 non-null      float64
#  12  AST_PCT            2 non-null      float64
#  13  AST_TOV            2 non-null      float64
#  14  AST_RATIO          2 non-null      float64
#  15  OREB_PCT           2 non-null      float64
# ...

# %%
from nba_api.stats.endpoints import boxscoretraditionalv2
game_id='0022100001'
leaguegames=boxscoretraditionalv2.BoxScoreTraditionalV2(game_id).get_data_frames()[1]
leaguegames
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION  TEAM_CITY     MIN  FGM  \
# 0  0022100001  1610612749     Bucks               MIL  Milwaukee  240:00   48
# 1  0022100001  1610612751      Nets               BKN   Brooklyn  240:00   37
#
#    FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  \
# 0  105   0.457    17    45    0.378   14   18   0.778    13    41   54   25
# 1   84   0.440    17    32    0.531   13   23   0.565     5    39   44   19
#
#    STL  BLK  TO  PF  PTS  PLUS_MINUS
# 0    8    9   7  19  127        23.0
# 1    3    9  12  17  104       -23.0

# %%
from nba_api.stats.endpoints import boxscoretraditionalv2
game_null='00'
for i in range(22100002,22101225):
    game_id=game_null+str(i)
    leaguegame=boxscoretraditionalv2.BoxScoreTraditionalV2(game_id).get_data_frames()[1]
    leaguegames=leaguegames.append(leaguegame)
leaguegames
# Out:
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\urllib3\util\connection.py in create_connection(address, timeout, source_address, socket_options)
#      85                 sock.bind(source_address)
# ---> 86             sock.connect(sa)
#      87             return sock
#
# TimeoutError: [WinError 10060] 連線嘗試失敗，因為連線對象有一段時間並未正確回應，或是連線建立失敗，因為連線的主機無法回應。
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15624/398566523.py in <module>
#       3 for i in range(22100002,22101225):
#       4     game_id=game_null+str(i)
# ----> 5     leaguegame=boxscoretraditionalv2.BoxScoreTraditionalV2(game_id).get_data_frames()[1]
#       6     leaguegames=leaguegames.append(leaguegame)
#       7 leaguegames
#
# ...

# %%
for i in range(22100002,22101225):
    game_id=game_null+str(i)
    print(game_id)
# Out:
# 0022100002
# 0022100003
# 0022100004
# 0022100005
# 0022100006
# 0022100007
# 0022100008
# 0022100009
# 0022100010
# 0022100011
# 0022100012
# 0022100013
# 0022100014
# 0022100015
# 0022100016
# 0022100017
# 0022100018
# 0022100019
# 0022100020
# 0022100021
# 0022100022
# 0022100023
# 0022100024
# 0022100025
# 0022100026
# 0022100027
# 0022100028
# 0022100029
# 0022100030
# 0022100031
# 0022100032
# 0022100033
# 0022100034
# 0022100035
# 0022100036
# 0022100037
# 0022100038
# 0022100039
# 0022100040
# 0022100041
# 0022100042
# 0022100043
# 0022100044
# 0022100045
# 0022100046
# 0022100047
# 0022100048
# 0022100049
# 0022100050
# 0022100051
# 0022100052
# 0022100053
# 0022100054
# 0022100055
# 0022100056
# 0022100057
# 0022100058
# 0022100059
# 0022100060
# 0022100061
# 0022100062
# 0022100063
# 0022100064
# 0022100065
# 0022100066
# 0022100067
# 0022100068
# 0022100069
# 0022100070
# 0022100071
# 0022100072
# 0022100073
# 0022100074
# 0022100075
# 0022100076
# 0022100077
# ...

# %%
game_null='00'
for i in range(22100002,22101225):
    game_id=game_null+str(i)
    leaguegames=boxscoreadvancedv2.BoxScoreAdvancedV2(game_id).get_data_frames()[1]
    leaguegame=leaguegame.append(leaguegames)
leaguegame
